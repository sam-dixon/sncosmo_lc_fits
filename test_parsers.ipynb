# %%
import pickle
import sncosmo
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table

# %% [markdown]
# # CSP

# %%
csp = pickle.load(open('data/csp_lcs.pkl', 'rb'))

# %%
csp.keys()
# Out:
# dict_keys(['SN2008J', 'SN2005kc', 'SN2005A', 'SN2009Y', 'SN2004gs', 'SN2004eo', 'SN2008gp', 'SN2007ca', 'SN2009al', 'SN2008ae', 'SN2006dd', 'SN2005ki', 'SN2007if', 'SN2006D', 'SN2006lu', 'SN2009ag', 'SN2006ev', 'SN2009cz', 'SN2006gj', 'SN2005el', 'SN2007jh', 'SN2007so', 'SN2006gt', 'SN2007ai', 'SN2006hb', 'SN2007hj', 'SN2008ia', 'SN2007ol', 'SN2008fw', 'SN2005mc', 'SN2009dc', 'SN2009F', 'SN2008go', 'SN2008cf', 'SN2006bd', 'SN2007bm', 'SN2006kf', 'SN2008bt', 'SN2006mr', 'SN2007le', 'SN2008hu', 'SN2009J', 'SN2007N', 'SN2006ob', 'SN2006bh', 'SN2007ba', 'SN2008fp', 'SN2005na', 'SN2008R', 'SN2005bg', 'SN2005ke', 'SN2007cg', 'SN2004gu', 'SN2007jd', 'SN2007hx', 'SN2008ha', 'SN2005hj', 'SN2005hk', 'SN2005ir', 'SN2005bl', 'SN2005M', 'SN2008bf', 'SN2006eq', 'SN2009aa', 'SN2008hj', 'SN2006ax', 'SN2009D', 'SN2008gl', 'SN2008cd', 'SN2007A', 'SN2008ar', 'SN2006X', 'SN2006ej', 'SN2005eq', 'SN2008gg', 'SN2004ey', 'SN2010ae', 'SN2007ux', 'SN2005W', 'SN2007on', 'SN2005ku', 'SN2008fu', 'SN2007bd', 'SN2006is', 'SN2008bc', 'SN2007mm', 'SN2008C', 'SN2004dt', 'SN2006br', 'SN2005ag', 'SN2007sr', 'SN2009ad', 'SN2006et', 'SN2009P', 'SN2004ef', 'SN2006os', 'SN2008bi', 'SN2009le', 'SN2005al', 'SN2005am', 'SN2005iq', 'SN2008bd', 'SN2007S', 'SN2005bo', 'SN2006bt', 'SN2008fl', 'SN2007st', 'SN2005hc', 'SN2009ab', 'SN2007as', 'SN2006hx', 'SN2008ff', 'SN2009ds', 'SN2008O', 'SN2006ot', 'SN2006py', 'SN2005be', 'SN2006fw', 'SN2007ax', 'SN2007jg', 'SN2007af', 'SN2008cc', 'SN2006ef', 'SN2007nq', 'SN2008bq', 'SN2008hv', 'SN2009I', 'SN2004gc', 'SN2005lu', 'SN2007al', 'SN2005gj', 'SN2008bz', 'SN2007bc', 'SN2008fr'])

# %%
random_lc = np.random.choice(list(csp.values()))

# %%
sncosmo.plot_lc(random_lc);

# %%
random_lc.meta
# Out:
# {'name': 'SN2006bh',
#  'survey': 'csp',
#  'z': 0.0109,
#  'mwebv': 0.022862200011365373,
#  't0': nan}

# %% [markdown]
# # DES

# %%
des = pickle.load(open('data/des_lcs.pkl', 'rb'))

# %%
random_lc = np.random.choice(list(des.values()))

# %%
sncosmo.plot_lc(random_lc);

# %%
random_lc.meta
# Out:
# {'name': '01303883',
#  'survey': 'des',
#  'z': 0.2591,
#  'mwebv': 0.01,
#  't0': 57284.078}

# %% [markdown]
# # Foundation

# %%
found = pickle.load(open('data/foundation_lcs.pkl', 'rb'))

# %%
random_lc = np.random.choice(list(found.values()))

# %%
random_lc
# Out:
# <Table length=26>
#        time                      band                 flux  ...    zp   zpsys
#      float64                    object              float64 ... float64  str2
# ------------------ -------------------------------- ------- ... ------- -----
#          57388.277 <Bandpass 'gp1' at 0x181cb99cc0> 23052.0 ...    27.5    ab
#          57394.285 <Bandpass 'gp1' at 0x181cb99cc0> 22032.0 ...    27.5    ab
# 57400.265999999996 <Bandpass 'gp1' at 0x181cb99cc0> 15560.0 ...    27.5    ab
#          57408.223 <Bandpass 'gp1' at 0x181cb99cc0>  8476.5 ...    27.5    ab
#           57416.25 <Bandpass 'gp1' at 0x181cb99cc0>  4704.5 ...    27.5    ab
#           57700.43 <Bandpass 'gp1' at 0x181cb99cc0>   108.7 ...    27.5    ab
#          57388.277 <Bandpass 'rp1' at 0x181cb99438> 24087.0 ...    27.5    ab
# 57400.265999999996 <Bandpass 'rp1' at 0x181cb99438> 18557.0 ...    27.5    ab
#          57408.223 <Bandpass 'rp1' at 0x181cb99438> 14431.0 ...    27.5    ab
#           57429.23 <Bandpass 'rp1' at 0x181cb99438>  7639.7 ...    27.5    ab
#                ...                              ...     ... ...     ...   ...
#           57439.23 <Bandpass 'ip1' at 0x181cb990b8>  5610.3 ...    27.5    ab
#          57700.434 <Bandpass 'ip1' at 0x181cb990b8>   237.4 ...    27.5    ab
#          57387.207 <Bandpass 'zp1' at 0x181ea2b438> 15518.0 ...    27.5    ab
#          57394.285 <Bandpass 'zp1' at 0x181ea2b438> 14656.0 ...    27.5    ab
# 57400.265999999996 <Bandpass 'zp1' at 0x181ea2b438> 14410.0 ...    27.5    ab
#          57408.223 <Bandpass 'zp1' at 0x181ea2b438> 13522.0 ...    27.5    ab
#           57416.25 <Bandpass 'zp1' at 0x181ea2b438> 12508.0 ...    27.5    ab
#           57429.23 <Bandpass 'zp1' at 0x181ea2b438>  8475.7 ...    27.5    ab
#           57439.23 <Bandpass 'zp1' at 0x181ea2b438>  5884.9 ...    27.5    ab
#          57700.434 <Bandpass 'zp1' at 0x181ea2b438>    50.1 ...    27.5    ab

# %%
sncosmo.plot_lc(random_lc);

# %% [markdown]
# # JLA

# %%
jla = pickle.load(open('data/jla_lcs.pkl', 'rb'))

# %%
random_lc = np.random.choice(list(jla.values()))

# %%
sncosmo.plot_lc(random_lc);

# %%
random_lc.meta
# Out:
# {'name': '04D4in',
#  'survey': 'SNLS',
#  'z': 0.516,
#  'mwebv': 0.0253,
#  't0': 53278.847}

# %% [markdown]
# # PS1

# %%
ps = pickle.load(open('data/ps1_lcs.pkl', 'rb'))

# %%
random_lc = np.random.choice(list(ps.values()))

# %%
sncosmo.plot_lc(random_lc);

# %%
random_lc.meta
# Out:
# OrderedDict([('SURVEY', 'PS1MD'),
#              ('SNID', 'PSc320492'),
#              ('IAUC', 'UNKNOWN'),
#              ('RA', 35.3817542),
#              ('DECL', -3.0890861),
#              ('MWEBV', 0.0225),
#              ('REDSHIFT_FINAL', 0.4872),
#              ('HOSTGAL_LOGMASS', 9.394),
#              ('SEARCH_PEAKMJD', 55859.0),
#              ('FILTERS', 'griz'),
#              ('processing', '#'),
#              ('PSFTRIM', 0),
#              ('PHOTCAT', 'PSc320492.0x1613.dougpv3.phot1'),
#              ('CNTRD_FLUX_OFFSET', 0.0009),
#              ('HOSTNAME', 'dsp056'),
#              ('NOBS', 400),
#              ('END', None)])

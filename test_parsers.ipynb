# %%
import pickle
import sncosmo
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table

# %% [markdown]
# # CSP

# %%
csp = pickle.load(open('data/csp_lcs.pkl', 'rb'))

# %%
csp.keys()
# Out:
# dict_keys(['SN2008J', 'SN2005kc', 'SN2005A', 'SN2009Y', 'SN2004gs', 'SN2004eo', 'SN2008gp', 'SN2007ca', 'SN2009al', 'SN2008ae', 'SN2006dd', 'SN2005ki', 'SN2007if', 'SN2006D', 'SN2006lu', 'SN2009ag', 'SN2006ev', 'SN2009cz', 'SN2006gj', 'SN2005el', 'SN2007jh', 'SN2007so', 'SN2006gt', 'SN2007ai', 'SN2006hb', 'SN2007hj', 'SN2008ia', 'SN2007ol', 'SN2008fw', 'SN2005mc', 'SN2009dc', 'SN2009F', 'SN2008go', 'SN2008cf', 'SN2006bd', 'SN2007bm', 'SN2006kf', 'SN2008bt', 'SN2006mr', 'SN2007le', 'SN2008hu', 'SN2009J', 'SN2007N', 'SN2006ob', 'SN2006bh', 'SN2007ba', 'SN2008fp', 'SN2005na', 'SN2008R', 'SN2005bg', 'SN2005ke', 'SN2007cg', 'SN2004gu', 'SN2007jd', 'SN2007hx', 'SN2008ha', 'SN2005hj', 'SN2005hk', 'SN2005ir', 'SN2005bl', 'SN2005M', 'SN2008bf', 'SN2006eq', 'SN2009aa', 'SN2008hj', 'SN2006ax', 'SN2009D', 'SN2008gl', 'SN2008cd', 'SN2007A', 'SN2008ar', 'SN2006X', 'SN2006ej', 'SN2005eq', 'SN2008gg', 'SN2004ey', 'SN2010ae', 'SN2007ux', 'SN2005W', 'SN2007on', 'SN2005ku', 'SN2008fu', 'SN2007bd', 'SN2
# ...

# %%
random_lc = np.random.choice(list(csp.values()))

# %%
sncosmo.plot_lc(random_lc);

# %%
random_lc.meta
# Out:
# {'name': 'SN2006os',
#  'survey': 'csp',
#  'z': 0.0328,
#  'mwebv': 0.12540838006801724,
#  't0': nan}

# %% [markdown]
# # DES

# %%
des = pickle.load(open('data/des_lcs.pkl', 'rb'))

# %%
random_lc = np.random.choice(list(des.values()))

# %%
random_lc
# Out:
# <Table length=48>
#    MJD    band FIELD   flux  flux_err ...   GAIN  PHOTFLAG PHOTPROB zpsys
#  float64  str4  str2 float64 float64  ... float64  int64   float64   str2
# --------- ---- ----- ------- -------- ... ------- -------- -------- -----
# 57325.068 desg    X1  -7.753   11.874 ...    3.87        0     0.91    ab
# 57325.071 desr    X1 -21.749   12.481 ...    3.78        0     0.93    ab
# 57325.073 desi    X1 -14.341   12.548 ...    3.84        0     0.84    ab
# 57325.075 desz    X1    6.24   15.341 ...   3.982        0     0.89    ab
# 57329.057 desg    X1   0.574   5.9706 ...    3.68        0     0.83    ab
# 57329.059 desr    X1  -5.598   8.0446 ...    3.67        0     0.79    ab
# 57329.062 desi    X1 -15.312   10.108 ...    3.81        0      0.9    ab
# 57329.064 desz    X1 -19.525   13.284 ...   3.995        0     0.86    ab
# 57339.033 desg    X1  -12.04   6.9527 ...    3.73        0     0.95    ab
# ...

# %%
sncosmo.plot_lc(random_lc);

# %%
random_lc.meta
# Out:
# {'name': '01334470',
#  'survey': 'des',
#  'z': 0.5188,
#  'mwebv': 0.019,
#  't0': 57332.941}

# %% [markdown]
# # Foundation

# %%
found = pickle.load(open('data/foundation_lcs.pkl', 'rb'))

# %%
random_lc = np.random.choice(list(found.values()))

# %%
random_lc
# Out:
# <Table length=32>
#        time                      band                 flux  ...    zp   zpsys
#      float64                    object              float64 ... float64  str2
# ------------------ -------------------------------- ------- ... ------- -----
#          57448.285  <Bandpass 'gp1' at 0x108250ac8> 22702.0 ...    27.5    ab
#           57452.25  <Bandpass 'gp1' at 0x108250ac8> 28997.0 ...    27.5    ab
#          57457.238  <Bandpass 'gp1' at 0x108250ac8> 30424.0 ...    27.5    ab
# 57462.234000000004  <Bandpass 'gp1' at 0x108250ac8> 24418.0 ...    27.5    ab
# 57475.265999999996  <Bandpass 'gp1' at 0x108250ac8> 11203.0 ...    27.5    ab
#          57490.242  <Bandpass 'gp1' at 0x108250ac8>  4160.4 ...    27.5    ab
#          57498.246  <Bandpass 'gp1' at 0x108250ac8>  2859.6 ...    27.5    ab
#          57448.285 <Bandpass 'rp1' at 0x1815aea7f0> 21077.0 ...    27.5    ab
#           57452.25 <Bandpass 'rp1' at 0x1815aea7f0> 26917.0 ...    27.5    ab
# ...

# %%
sncosmo.plot_lc(random_lc);

# %% [markdown]
# # JLA

# %%
jla = pickle.load(open('data/jla_lcs.pkl', 'rb'))

# %%
jla.keys()
# Out:
# dict_keys(['05D4bj', 'SDSS18466', '05D2mp', 'SDSS14279', '04D4ib', 'SDSS15203', '05D3lr', 'sn2006td', 'SDSS16213', 'sn1992ag', 'sn2006ej', 'SDSS8213', 'SDSS1032', 'SDSS16069', 'SDSS12883', 'SDSS21033', 'SDSS15583', 'SDSS5533', 'sn2006bt', '06D4ce', 'SDSS15868', '05D2by', '05D3hs', 'sn2000ca', '03D4ag', 'sn2002bf', 'SDSS16100', '06D2gb', 'SDSS6108', 'SDSS6558', 'SDSS17253', 'sn1990af', 'SDSS15901', 'sn2001eh', 'SDSS18325', 'Torngasek', '06D2cc', 'SDSS17880', 'SDSS12856', 'SDSS16116', 'SDSS13894', '05D2dt', 'SDSS15872', 'SDSS15171', 'sn2006qo', 'SDSS16618', '05D3gv', '04D1sk', 'SDSS18485', '05D4bf', 'SDSS7847', 'SDSS14019', '05D1az', '05D1cc', '06D4bo', 'SDSS4046', 'SDSS15433', '05D1hk', 'SDSS16073', '04D4in', '05D3mx', 'sn2004as', 'SDSS19543', 'SDSS15425', '05D4fg', 'SDSS12860', 'SDSS15219', 'sn1997do', 'SDSS19282', 'SDSS12972', 'SDSS16032', '03D4dy', 'sn2007co', 'SDSS17208', 'SDSS19353', '05D1ix', '04D1rx', 'SDSS13070', 'SDSS17875', 'SDSS13135', 'SDSS6780', 'sn2003ch', '04D3ez', '04D
# ...

# %%
random_lc = np.random.choice(list([x for x in jla.values()]))

# %%
random_lc
# Out:
# <Table length=112>
#    time     flux  fluxerr    zp     band  zpsys
#  float64  float64 float64 float64   str7   str6
# --------- ------- ------- ------- ------- ------
# 53622.227    8.12  19.668    27.5 sdss::g AB_B12
# 53622.227  -71.07  30.222    27.5 sdss::r AB_B12
# 53622.227     6.6   43.47    27.5 sdss::i AB_B12
# 53622.227 -166.93 141.505    27.5 sdss::z AB_B12
# 53622.227  150.91  54.068    27.5 sdss::u AB_B12
# 53625.223     0.7  17.371    27.5 sdss::g AB_B12
# 53625.223   23.51  21.302    27.5 sdss::r AB_B12
# 53625.223   33.69  31.354    27.5 sdss::i AB_B12
# 53625.223  -11.34  96.379    27.5 sdss::z AB_B12
# 53625.223  -30.21  45.899    27.5 sdss::u AB_B12
#       ...     ...     ...     ...     ...    ...
# 53704.109   42.94  16.157    27.5 sdss::g AB_B12
# 53704.109   53.19  25.455    27.5 sdss::r AB_B12
# 53704.109   31.41  38.833    27.5 sdss::i AB_B12
# 53704.109  105.49 126.215    27.5 sdss::z AB_B12
# 53704.109 -113.18  45.098    27.5 sdss::u AB_B12
# ...

# %%
sncosmo.plot_lc(random_lc);

# %%
random_lc.meta
# Out:
# {'name': 'SDSS6699',
#  'survey': 'SDSS',
#  'z': 0.3106,
#  'mwebv': 0.0547,
#  't0': 53675.445}

# %% [markdown]
# # PS1

# %%
ps = pickle.load(open('data/ps1_lcs.pkl', 'rb'))

# %%
random_lc = np.random.choice(list(ps.values()))

# %%
sncosmo.plot_lc(random_lc);
print(random_lc.meta['z'])
# Out:
# 0.2707

# %%
random_lc.colnames
# Out:
# ['MJD', 'band', 'FIELD', 'flux', 'flux_err', 'MAG', 'MAGERR', 'zpsys', 'zp']

# %%
random_lc.meta
# Out:
# {'name': 'psc160039',
#  'survey': 'ps1',
#  'z': 0.2707,
#  'mwebv': 0.0102,
#  't0': 55694.0}
